# %% [markdown]
# # CAGE Local Results
# This notebook summarizes the latest local baseline results and plots.

# %%
import pandas as pd
from pathlib import Path
summary = Path('experiments/plots/latest_metrics_summary.csv')
df = pd.read_csv(summary)
df

# %%
from IPython.display import Image, display
plots = [
    'experiments/plots/qps_by_baseline.png',
    'experiments/plots/ttft_by_baseline.png',
    'experiments/plots/latency_by_baseline.png',
    'experiments/plots/bertscore_by_baseline.png',
    'experiments/plots/tradeoff_latency_vs_bertscore.png',
]
for p in plots:
    display(Image(filename=p))
